# %% [markdown]
# ## Практична робота 08.10
# #### Створити автокодувальник для датасету рукописних цифр за допомогою бібліотеки Keras (використовуємо тільки звичайні шари).

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from keras import layers, models

# %% [markdown]
# ### Побудувати автокодувальник без шуму, графік функції втрат, результати розпізнавання.

# %%
(x_train, _), (x_test, _) = tf.keras.datasets.mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %%
x_train = x_train.astype(np.float32) / 255
x_test = x_test.astype(np.float32) / 255

# %%
x_train = x_train.reshape(-1, 28 * 28)
x_test = x_test.reshape(-1, 28 * 28)
input_layer = layers.Input(shape=(784,))

# %%
# Побудова енкодера
encoded = layers.Dense(128, activation='relu')(input_layer)
encoded = layers.Dense(64, activation='relu')(encoded)
encoded = layers.Dense(32, activation='relu')(encoded)

# Побудова декодера
decoded = layers.Dense(64, activation='relu')(encoded)
decoded = layers.Dense(128, activation='relu')(decoded)
decoded = layers.Dense(784, activation='sigmoid')(decoded)

# Створення автоенкодера
autoencoder = models.Model(input_layer, decoded)
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# %% [markdown]
# ### Навчання моделі

# %%
history = autoencoder.fit(
    x_train,
    x_train,
    epochs=50,
    batch_size=256,
    shuffle=True,
    validation_data=(x_test, x_test)
)

# Відновлені зображення
decoded_images = autoencoder.predict(x_test)
# Out:
# Epoch 1/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.3428 - val_loss: 0.1711
# Epoch 2/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1624 - val_loss: 0.1362
# Epoch 3/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1335 - val_loss: 0.1226
# Epoch 4/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1225 - val_loss: 0.1158
# Epoch 5/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1159 - val_loss: 0.1110
# Epoch 6/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1113 - val_loss: 0.1075
# Epoch 7/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1079 - val_loss: 0.1046
# Epoch 8/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1050 - val_loss: 0.1020
# Epoch 9/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1024 - val_loss: 0.1000
# Epoch 10/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1006 - val_loss: 0.0981
# Epoch 11/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0990 - val_loss: 0.0981
# Epoch 12/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0979 - val_loss: 0.0957
# Epoch 13/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0964 - val_loss: 0.0948
# Epoch 14/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0956 - val_loss: 0.0943
# Epoch 15/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0946 - val_loss: 0.0930
# Epoch 16/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0937 - val_loss: 0.0923
# Epoch 17/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0931 - val_loss: 0.0918
# Epoch 18/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0923 - val_loss: 0.0910
# Epoch 19/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0914 - val_loss: 0.0900
# Epoch 20/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0911 - val_loss: 0.0898
# Epoch 21/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0904 - val_loss: 0.0892
# Epoch 22/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0900 - val_loss: 0.0892
# Epoch 23/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0896 - val_loss: 0.0883
# Epoch 24/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0891 - val_loss: 0.0880
# Epoch 25/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0888 - val_loss: 0.0879
# Epoch 26/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0883 - val_loss: 0.0873
# Epoch 27/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0879 - val_loss: 0.0870
# Epoch 28/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0878 - val_loss: 0.0867
# Epoch 29/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0873 - val_loss: 0.0866
# Epoch 30/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0870 - val_loss: 0.0865
# Epoch 31/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0867 - val_loss: 0.0862
# Epoch 32/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0865 - val_loss: 0.0859
# Epoch 33/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0864 - val_loss: 0.0854
# Epoch 34/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0860 - val_loss: 0.0854
# Epoch 35/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0859 - val_loss: 0.0854
# Epoch 36/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0857 - val_loss: 0.0852
# Epoch 37/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0855 - val_loss: 0.0849
# Epoch 38/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0852 - val_loss: 0.0847
# Epoch 39/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0852 - val_loss: 0.0846
# Epoch 40/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0849 - val_loss: 0.0842
# Epoch 41/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0847 - val_loss: 0.0842
# Epoch 42/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0845 - val_loss: 0.0840
# Epoch 43/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0844 - val_loss: 0.0840
# Epoch 44/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0843 - val_loss: 0.0838
# Epoch 45/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0841 - val_loss: 0.0837
# Epoch 46/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0837 - val_loss: 0.0834
# Epoch 47/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0839 - val_loss: 0.0834
# Epoch 48/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0837 - val_loss: 0.0832
# Epoch 49/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0835 - val_loss: 0.0832
# Epoch 50/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0833 - val_loss: 0.0829
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 843us/step

# %%
decoded_images = autoencoder.predict(x_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 717us/step

# %%
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Навчальна втрата')
plt.plot(history.history['val_loss'], label='Втрата валідації')
plt.title('Функція втрат автоенкодера')
plt.xlabel('Епоха')
plt.ylabel('Втрата')
plt.legend()
plt.grid()
plt.show()

# %%
num_images = 10
plt.figure(figsize=(20, 4))

for i in range(num_images):
    # Відображення оригінального зображення
    plt.subplot(2, num_images, i + 1)
    plt.imshow(x_test[i].reshape(28, 28), cmap='gray')
    plt.title(f"Оригінал")
    plt.axis('off')

    # Відображення відновленого зображення
    plt.subplot(2, num_images, i + 1 + num_images)
    plt.imshow(decoded_images[i].reshape(28, 28), cmap='gray')
    plt.title(f"Відновлено")
    plt.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Побудувати автокодувальник із шумом, графік функції втрат, результати розпізнавання.

# %%
def add_noise(images, noise_factor=0.5):
    noisy_images = images + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=images.shape)
    return np.clip(noisy_images, 0., 1.)

# %%
(x_train, _), (x_test, _) = tf.keras.datasets.mnist.load_data()
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0
x_train = x_train.reshape((len(x_train), -1))
x_test = x_test.reshape((len(x_test), -1))

# %%
x_train_noisy = add_noise(x_train)
x_test_noisy = add_noise(x_test)

# %%
input_layer = layers.Input(shape=(784,))
encoded = layers.Dense(128, activation='relu')(input_layer)
encoded = layers.Dense(64, activation='relu')(encoded)
encoded = layers.Dense(32, activation='relu')(encoded)
decoded = layers.Dense(64, activation='relu')(encoded)
decoded = layers.Dense(128, activation='relu')(decoded)
decoded = layers.Dense(784, activation='sigmoid')(decoded)

autoencoder = models.Model(input_layer, decoded)
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')


history = autoencoder.fit(
    x_train_noisy,
    x_train,
    epochs=50,
    batch_size=256,
    shuffle=True,
    validation_data=(x_test_noisy, x_test)
)

decoded_imgs_noisy = autoencoder.predict(x_test_noisy)
# Out:
# Epoch 1/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.3438 - val_loss: 0.2147
# Epoch 2/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2030 - val_loss: 0.1752
# Epoch 3/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1712 - val_loss: 0.1598
# Epoch 4/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1580 - val_loss: 0.1518
# Epoch 5/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1516 - val_loss: 0.1473
# Epoch 6/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1471 - val_loss: 0.1435
# Epoch 7/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1432 - val_loss: 0.1405
# Epoch 8/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1405 - val_loss: 0.1379
# Epoch 9/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1381 - val_loss: 0.1364
# Epoch 10/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1362 - val_loss: 0.1346
# Epoch 11/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1343 - val_loss: 0.1331
# Epoch 12/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1328 - val_loss: 0.1318
# Epoch 13/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1314 - val_loss: 0.1303
# Epoch 14/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1298 - val_loss: 0.1291
# Epoch 15/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1283 - val_loss: 0.1282
# Epoch 16/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1276 - val_loss: 0.1271
# Epoch 17/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1263 - val_loss: 0.1264
# Epoch 18/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1257 - val_loss: 0.1259
# Epoch 19/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1250 - val_loss: 0.1251
# Epoch 20/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1242 - val_loss: 0.1249
# Epoch 21/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1238 - val_loss: 0.1241
# Epoch 22/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1233 - val_loss: 0.1244
# Epoch 23/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1224 - val_loss: 0.1240
# Epoch 24/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1223 - val_loss: 0.1232
# Epoch 25/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1220 - val_loss: 0.1232
# Epoch 26/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1215 - val_loss: 0.1228
# Epoch 27/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1213 - val_loss: 0.1223
# Epoch 28/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1207 - val_loss: 0.1217
# Epoch 29/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1204 - val_loss: 0.1214
# Epoch 30/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1202 - val_loss: 0.1215
# Epoch 31/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1196 - val_loss: 0.1213
# Epoch 32/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1193 - val_loss: 0.1213
# Epoch 33/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1190 - val_loss: 0.1208
# Epoch 34/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1189 - val_loss: 0.1205
# Epoch 35/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1187 - val_loss: 0.1205
# Epoch 36/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1181 - val_loss: 0.1197
# Epoch 37/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1180 - val_loss: 0.1198
# Epoch 38/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1179 - val_loss: 0.1197
# Epoch 39/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1176 - val_loss: 0.1196
# Epoch 40/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1175 - val_loss: 0.1191
# Epoch 41/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1170 - val_loss: 0.1193
# Epoch 42/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1169 - val_loss: 0.1190
# Epoch 43/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1169 - val_loss: 0.1188
# Epoch 44/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1165 - val_loss: 0.1187
# Epoch 45/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1164 - val_loss: 0.1185
# Epoch 46/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1161 - val_loss: 0.1187
# Epoch 47/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1163 - val_loss: 0.1186
# Epoch 48/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1158 - val_loss: 0.1184
# Epoch 49/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1156 - val_loss: 0.1185
# Epoch 50/50
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1155 - val_loss: 0.1181
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 828us/step

# %%
num_images = 10
plt.figure(figsize=(20, 6))

for i in range(num_images):
    plt.subplot(3, num_images, i + 1)
    plt.imshow(x_test_noisy[i].reshape(28, 28), cmap='gray')
    plt.title(f"Зашумлене")
    plt.axis('off')

    plt.subplot(3, num_images, i + 1 + num_images)
    plt.imshow(x_test[i].reshape(28, 28), cmap='gray')
    plt.title(f"Оригінал")
    plt.axis('off')

    plt.subplot(3, num_images, i + 1 + 2*num_images)
    plt.imshow(decoded_imgs_noisy[i].reshape(28, 28), cmap='gray')
    plt.title(f"Відновлено")
    plt.axis('off')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Навчальна втрата')
plt.plot(history.history['val_loss'], label='Втрата валідації')
plt.title('Функція втрат автоенкодера')
plt.xlabel('Епоха')
plt.ylabel('Втрата')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ### Розподіл векторів прихованого шару

# %%
h = autoencoder.predict(x_test)

# Зменшення розмірності до 2D
pca = PCA(n_components=2)
h_reduced = pca.fit_transform(h)

plt.figure(figsize=(10, 6))
plt.scatter(h_reduced[:, 0], h_reduced[:, 1], alpha=0.5)
plt.title('2D Візуалізація ознак автоенкодера')
plt.xlabel('Перша головна компонента')
plt.ylabel('Друга головна компонента')
plt.grid()
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 738us/step

# %% [markdown]
# # Висновок
#
# ### В цій практичній роботі було створено автоенкодер для відновлення зображень з набору даних MNIST. Після нормалізації та внесення шуму, модель показала високу здатність відновлювати початкові зображення, навіть у зашумленому стані. Отримані результати підкреслюють високу ефективність моделі, що відкриває перспективи для подальших досліджень у галузі обробки зображень і машинного навчання.
